# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mk8_df.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703560 entries, 0 to 703559
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   perso   703560 non-null  object
#  1   kart    703560 non-null  object
#  2   wheels  703560 non-null  object
#  3   glider  703560 non-null  object
#  4   WG      703560 non-null  float64
#  5   AC      703560 non-null  float64
#  6   ON      703560 non-null  float64
#  7   OF      703560 non-null  float64
#  8   MT      703560 non-null  float64
#  9   SL      703560 non-null  float64
#  10  SW      703560 non-null  float64
#  11  SA      703560 non-null  float64
#  12  SG      703560 non-null  float64
#  13  TL      703560 non-null  float64
#  14  TW      703560 non-null  float64
#  15  TA      703560 non-null  float64
#  16  TG      703560 non-null  float64
#  17  IV      703560 non-null  float64
# dtypes: float64(14), object(4)
# memory usage: 96.6+ MB

# %%
df.describe()
# Out:
#                   WG             AC             ON             OF  \
# count  703560.000000  703560.000000  703560.000000  703560.000000
# mean        3.305528       3.353794       3.530410       3.325988
# std         0.921570       0.787137       0.820711       0.833162
# min         0.750000       1.000000       1.250000       0.750000
# 25%         2.500000       2.750000       3.000000       2.750000
# 50%         3.250000       3.250000       3.500000       3.250000
# 75%         4.000000       4.000000       4.000000       4.000000
# max         5.750000       5.750000       5.750000       5.750000
#
#                   MT             SL             SW             SA  \
# count  703560.000000  703560.000000  703560.000000  703560.000000
# mean        3.946985       3.724099       3.597713       3.691301
# std         0.595267       0.813498       0.791722       0.798225
# min         2.250000       1.000000       1.250000       1.000000
# ...

# %%
combi = ['Yoshi Ysi 1', 'Sport Bike', 'Azure Roller', 'Paper Glider']

# %%
df.columns
# Out:
# Index(['perso', 'kart', 'wheels', 'glider', 'WG', 'AC', 'ON', 'OF', 'MT', 'SL',
#        'SW', 'SA', 'SG', 'TL', 'TW', 'TA', 'TG', 'IV'],
#       dtype='object')

# %%
combi_test_list = ['perso', 'kart', 'wheels', 'glider', 'SL', 'AC', 'WG', 'TL', 'OF']

# %%
df0 = df[combi_test_list]
df0
# Out:
#             perso               kart                       wheels  \
# 0       Mario Mro      Standard Kart              Standard Normal
# 1       Mario Mro      Standard Kart              Standard Normal
# 2       Mario Mro      Standard Kart              Standard Normal
# 3       Mario Mro      Standard Kart              Standard Normal
# 4       Mario Mro      Standard Kart              Standard Normal
# ...           ...                ...                          ...
# 703555    Pauline  Master Cycle Zero  Ancient Tires Ancient Tyres
# 703556    Pauline  Master Cycle Zero  Ancient Tires Ancient Tyres
# 703557    Pauline  Master Cycle Zero  Ancient Tires Ancient Tyres
# 703558    Pauline  Master Cycle Zero  Ancient Tires Ancient Tyres
# 703559    Pauline  Master Cycle Zero  Ancient Tires Ancient Tyres
#
#                glider    SL    AC    WG    TL    OF
# 0        Super Glider  4.00  3.50  3.50  3.50  3.50
# 1        Cloud Glider  3.75  3.75  3.25  3.50  3.50
# ...

# %%
df1 = df0[df0['perso'] == 'Yoshi Ysi 1']
#df2 = df1[df1['kart'] == 'Yoshi Bike']
df3 = df1[df1['wheels'] == 'Azure Roller']
df4 = df3[df3['glider'] == 'Paper Glider'] 
df4
# Out:
#              perso                        kart        wheels        glider  \
# 54328  Yoshi Ysi 1               Standard Kart  Azure Roller  Paper Glider
# 54658  Yoshi Ysi 1                  Pipe Frame  Azure Roller  Paper Glider
# 54988  Yoshi Ysi 1                      Mach 8  Azure Roller  Paper Glider
# 55318  Yoshi Ysi 1                Steel Driver  Azure Roller  Paper Glider
# 55648  Yoshi Ysi 1                 Cat Cruiser  Azure Roller  Paper Glider
# 55978  Yoshi Ysi 1             Circuit Special  Azure Roller  Paper Glider
# 56308  Yoshi Ysi 1                 Tri-Speeder  Azure Roller  Paper Glider
# 56638  Yoshi Ysi 1                    Badwagon  Azure Roller  Paper Glider
# 56968  Yoshi Ysi 1                     Prancer  Azure Roller  Paper Glider
# 57298  Yoshi Ysi 1         Biddybuggy Buggybud  Azure Roller  Paper Glider
# 57628  Yoshi Ysi 1                    Landship  Azure Roller  Paper Glider
# ...

# %%
df.kart.value_counts()
# Out:
# Standard Kart                 17160
# Jet Bike                      17160
# Standard ATV Standard Quad    17160
# Wild Wiggler                  17160
# Teddy Buggy                   17160
# GLA                           17160
# W 25 Silver Arrow             17160
# 300 SL Roadster               17160
# Blue Falcon                   17160
# Tanooki Kart                  17160
# B Dasher                      17160
# Master Cycle                  17160
# Streetle                      17160
# P-Wing                        17160
# City Tripper                  17160
# Bone Rattler                  17160
# Koopa Clown                   17160
# Splat Buggy                   17160
# Inkstriker                    17160
# Yoshi Bike                    17160
# Mr. Scooty Mr Scooty          17160
# Pipe Frame                    17160
# Varmint                       17160
# Mach 8                        17160
# Steel Driver                  17160
# Cat Cruiser                   17160
# ...
